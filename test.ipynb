# %%
from github_bug_data_collector.data_collector import DataCollector
from dotenv import load_dotenv
import os
import pandas as pd

load_dotenv()

token = os.getenv("ACCESS_TOKEN")
end_time = os.getenv("END_TIME")

collector = DataCollector(token)

df = collector.generate_dataframe("vercel", "next.js", labels=["bug"], until=pd.to_datetime(end_time))

display(df)
# Out:
# Getting issues: 100%|██████████| 10/10 [00:02<00:00,  3.85it/s]
# Converting issues to DataFrame: 100%|██████████| 10/10 [00:05<00:00,  1.84it/s]
# Getting user info: 100%|██████████| 10/10 [00:04<00:00,  2.05it/s]
#   number                                              title  created_at  \
# 0   7844  Development mode gets access to environment va...  1562691920
# 1  13092  CSS Modules styles defined in wrong order in d...  1589893767
# 2  14800  Namespace import is not defined during next bu...  1593707148
# 3  15212  Inconsistent css import order between Prod and...  1594886781
#
#    updated_at     closed_at     creator_name assignees_num labels_num   state  \
# 0  1720051455  1.718806e+09            Timer             2          3  closed
# 1  1715731452  1.714489e+09  jensmeindertsma             0          5  closed
# 2  1675382612  1.672789e+09    dvakatsiienko             0          3  closed
# 3  1714488756           NaN         figmentc             0          2    open
#
#   locked  ... reactions_eyes_num reactions_total_num time_to_next_issue  \
# 0      1  ...                  2                   7         27201847.0
# 1      1  ...                  0                  44          3813381.0
# 2      1  ...                  0                   0          1179633.0
# 3      0  ...                  0                   7                NaN
#
#   creator_company creator_followers_num creator_following_num  \
# 0         @vercel                  2460                    17
# 1            None                    17                     7
# 2            None                    71                    36
# 3            None                     2                     0
#
#   creator_public_repos_num creator_public_gists_num creator_created_at  \
# 0                      147                        4         1297643907
# 1                        9                        1         1588397526
# 2                        8                        1         1447065885
# 3                       25                        0         1470081614
#
#   creator_updated_at
# 0         1728930523
# 1         1726404444
# 2         1689445931
# 3         1716062092
#
# [4 rows x 29 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.dtypes
# Out:
# number                       object
# title                        object
# created_at                    int64
# updated_at                    int64
# closed_at                     int64
# creator_name                 object
# assignees_num                object
# labels_num                   object
# state                        object
# locked                       object
# author_association           object
# comments_num                 object
# reactions_+1_num             object
# reactions_-1_num             object
# reactions_laugh_num          object
# reactions_hooray_num         object
# reactions_confused_num       object
# reactions_heart_num          object
# reactions_rocket_num         object
# reactions_eyes_num           object
# reactions_total_num          object
# time_to_next_issue          float64
# creator_company              object
# creator_followers_num        object
# creator_following_num        object
# creator_public_repos_num     object
# creator_public_gists_num     object
# creator_created_at            int64
# creator_updated_at            int64
# dtype: object

# %%
import ydata_profiling


df.profile_report()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 import ydata_profiling
# ----> 4 df.profile_report()
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\IPython\core\displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\IPython\core\displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\IPython\core\formatters.py:182, in DisplayFormatter.format(self, obj, include, exclude)
#     180 md = None
#     181 try:
# --> 182     data = formatter(obj)
#     183 except:
#     184     # FIXME: log the exception
#     185     raise
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\IPython\core\formatters.py:226, in catch_format_error(method, self, *args, **kwargs)
#     224 """show traceback on failed format call"""
#     225 try:
# --> 226     r = method(self, *args, **kwargs)
#     227 except NotImplementedError:
#     228     # don't warn on NotImplementedErrors
#     229     return self._check_return(None, args[0])
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\IPython\core\formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\ydata_profiling\profile_report.py:540, in ProfileReport._repr_html_(self)
#     538 def _repr_html_(self) -> None:
#     539     """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 540     self.to_notebook_iframe()
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\ydata_profiling\profile_report.py:520, in ProfileReport.to_notebook_iframe(self)
#     518 with warnings.catch_warnings():
#     519     warnings.simplefilter("ignore")
# --> 520     display(get_notebook_iframe(self.config, self))
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\ydata_profiling\report\presentation\flavours\widget\notebook.py:75, in get_notebook_iframe(config, profile)
#      73     output = get_notebook_iframe_src(config, profile)
#      74 elif attribute == IframeAttribute.srcdoc:
# ---> 75     output = get_notebook_iframe_srcdoc(config, profile)
#      76 else:
#      77     raise ValueError(
#      78         f'Iframe Attribute can be "src" or "srcdoc" (current: {attribute}).'
#      79     )
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\ydata_profiling\report\presentation\flavours\widget\notebook.py:29, in get_notebook_iframe_srcdoc(config, profile)
#      27 width = config.notebook.iframe.width
#      28 height = config.notebook.iframe.height
# ---> 29 src = html.escape(profile.to_html())
#      31 iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#      33 return HTML(iframe)
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\ydata_profiling\profile_report.py:490, in ProfileReport.to_html(self)
#     482 def to_html(self) -> str:
#     483     """Generate and return complete template as lengthy string
#     484         for using with frameworks.
#     485
#    (...)
#     488
#     489     """
# --> 490     return self.html
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\ydata_profiling\profile_report.py:286, in ProfileReport.html(self)
#     283 @property
#     284 def html(self) -> str:
#     285     if self._html is None:
# --> 286         self._html = self._render_html()
#     287     return self._html
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\ydata_profiling\profile_report.py:403, in ProfileReport._render_html(self)
#     400 def _render_html(self) -> str:
#     401     from ydata_profiling.report.presentation.flavours import HTMLReport
# --> 403     report = self.report
#     405     with tqdm(
#     406         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     407     ) as pbar:
#     408         html = HTMLReport(copy.deepcopy(report)).render(
#     409             nav=self.config.html.navbar_show,
#     410             offline=self.config.html.use_local_assets,
#    (...)
#     418             version=self.description_set.package["ydata_profiling_version"],
#     419         )
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\ydata_profiling\profile_report.py:280, in ProfileReport.report(self)
#     277 @property
#     278 def report(self) -> Root:
#     279     if self._report is None:
# --> 280         self._report = get_report_structure(self.config, self.description_set)
#     281     return self._report
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\ydata_profiling\report\structure\report.py:387, in get_report_structure(config, summary)
#     368 section_items: List[Renderable] = [
#     369     Container(
#     370         get_dataset_items(config, summary, alerts),
#    (...)
#     374     ),
#     375 ]
#     377 if len(summary.variables) > 0:
#     378     section_items.append(
#     379         Dropdown(
#     380             name="Variables",
#     381             anchor_id="variables-dropdown",
#     382             id="variables-dropdown",
#     383             is_row=False,
#     384             classes=["form-select"],
#     385             items=list(summary.variables),
#     386             item=Container(
# --> 387                 render_variables_section(config, summary),
#     388                 sequence_type="accordion",
#     389                 name="Variables",
#     390                 anchor_id="variables",
#     391             ),
#     392         )
#     393     )
#     395 scatter_items = get_interactions(config, summary.scatter)
#     396 if len(scatter_items) > 0:
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\ydata_profiling\report\structure\report.py:162, in render_variables_section(config, dataframe_summary)
#     160     variable_type = summary["type"]
#     161 render_map_type = render_map.get(variable_type, render_map["Unsupported"])
# --> 162 template_variables.update(render_map_type(config, template_variables))
#     164 # Ignore these
#     165 if reject_variables:
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\ydata_profiling\report\structure\variables\render_categorical.py:412, in render_categorical(config, summary)
#     410 # length isn't being computed for categorical in spark
#     411 if length and "max_length" in summary:
# --> 412     length_table, length_histo = render_categorical_length(config, summary, varid)
#     413     overview_items.append(length_table)
#     415 # characters isn't being computed for categorical in spark
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\ydata_profiling\report\structure\variables\render_categorical.py:96, in render_categorical_length(config, summary, varid)
#      90     hist_data = histogram(
#      91         config,
#      92         [x[0] for x in summary["histogram_length"]],
#      93         [x[1] for x in summary["histogram_length"]],
#      94     )
#      95 else:
# ---> 96     hist_data = histogram(config, *summary["histogram_length"])
#      98 length_histo = Image(
#      99     hist_data,
#     100     image_format=config.plot.image_format,
#    (...)
#     104     anchor_id=f"{varid}length",
#     105 )
#     107 return length_table, length_histo
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\ydata_profiling\visualisation\plot.py:156, in histogram(config, series, bins, date)
#     137 @manage_matplotlib_context()
#     138 def histogram(
#     139     config: Settings,
#    (...)
#     142     date: bool = False,
#     143 ) -> str:
#     144     """Plot an histogram of the data.
#     145
#     146     Args:
#    (...)
#     154
#     155     """
# --> 156     plot = _plot_histogram(config, series, bins, date=date, figsize=(7, 3))
#     157     plot.xaxis.set_tick_params(rotation=90 if date else 45)
#     158     plot.figure.tight_layout()
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\ydata_profiling\visualisation\plot.py:108, in _plot_histogram(config, series, bins, figsize, date, hide_yaxis)
#     106 else:
#     107     fig = plt.figure(figsize=figsize)
# --> 108     plot = fig.add_subplot(111)
#     109     if not hide_yaxis:
#     110         plot.set_ylabel("Frequency")
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\matplotlib\figure.py:710, in FigureBase.add_subplot(self, *args, **kwargs)
#     708         args = tuple(map(int, str(args[0])))
#     709     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 710     ax = projection_class(self, *args, **pkw)
#     711     key = (projection_class, pkw)
#     712 return self._add_axes_internal(ax, key)
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\matplotlib\axes\_base.py:681, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     678 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     680 self._rasterization_zorder = None
# --> 681 self.clear()
#     683 # funcs used to format x and y - fall back on major formatters
#     684 self.fmt_xdata = None
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\matplotlib\axes\_base.py:1391, in _AxesBase.clear(self)
#    1389     self.cla()
#    1390 else:
# -> 1391     self.__clear()
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\matplotlib\axes\_base.py:1307, in _AxesBase.__clear(self)
#    1304 self.legend_ = None
#    1305 self.containers = []
# -> 1307 self.grid(False)  # Disable grid on init to use rcParameter
#    1308 self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1309           axis=mpl.rcParams['axes.grid.axis'])
#    1310 props = font_manager.FontProperties(
#    1311     size=mpl.rcParams['axes.titlesize'],
#    1312     weight=mpl.rcParams['axes.titleweight'])
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\matplotlib\axes\_base.py:3268, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3266 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3267 if axis in ['x', 'both']:
# -> 3268     self.xaxis.grid(visible, which=which, **kwargs)
#    3269 if axis in ['y', 'both']:
#    3270     self.yaxis.grid(visible, which=which, **kwargs)
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\matplotlib\axis.py:1741, in Axis.grid(self, visible, which, **kwargs)
#    1738 if which in ['major', 'both']:
#    1739     gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1740                         if visible is None else visible)
# -> 1741     self.set_tick_params(which='major', **gridkw)
#    1742 self.stale = True
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\matplotlib\axis.py:999, in Axis.set_tick_params(self, which, reset, **kwargs)
#     997 if which in ['major', 'both']:
#     998     self._major_tick_kw.update(kwtrans)
# --> 999     for tick in self.majorTicks:
#    1000         tick._apply_params(**kwtrans)
#    1001 if which in ['minor', 'both']:
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\matplotlib\axis.py:572, in _LazyTickList.__get__(self, instance, owner)
#     570 if self._major:
#     571     instance.majorTicks = []
# --> 572     tick = instance._get_tick(major=True)
#     573     instance.majorTicks.append(tick)
#     574     return instance.majorTicks
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\matplotlib\axis.py:1598, in Axis._get_tick(self, major)
#    1594     raise NotImplementedError(
#    1595         f"The Axis subclass {self.__class__.__name__} must define "
#    1596         "_tick_class or reimplement _get_tick()")
#    1597 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1598 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\matplotlib\axis.py:406, in XTick.__init__(self, *args, **kwargs)
#     404 # the y loc is 3 points below the min of y axis
#     405 trans, va, ha = self._get_text1_transform()
# --> 406 self.label1.set(
#     407     x=0, y=0,
#     408     verticalalignment=va, horizontalalignment=ha, transform=trans,
#     409 )
#     410 trans, va, ha = self._get_text2_transform()
#     411 self.label2.set(
#     412     x=0, y=1,
#     413     verticalalignment=va, horizontalalignment=ha, transform=trans,
#     414 )
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\matplotlib\artist.py:147, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     139 if not hasattr(cls.set, '_autogenerated_signature'):
#     140     # Don't overwrite cls.set if the subclass or one of its parents
#     141     # has defined a set method set itself.
#     142     # If there was no explicit definition, cls.set is inherited from
#     143     # the hierarchy of auto-generated set methods, which hold the
#     144     # flag _autogenerated_signature.
#     145     return
# --> 147 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148 cls.set.__name__ = "set"
#     149 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\matplotlib\artist.py:1224, in Artist.set(self, **kwargs)
#    1220 def set(self, **kwargs):
#    1221     # docstring and signature are auto-generated via
#    1222     # Artist._update_set_signature_and_docstring() at the end of the
#    1223     # module.
# -> 1224     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\matplotlib\artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\site-packages\matplotlib\artist.py:1181, in Artist._update_props(self, props, errfmt)
#    1174 """
#    1175 Helper for `.Artist.set` and `.Artist.update`.
#    1176
#    1177 *errfmt* is used to generate error messages for invalid property
#    1178 names; it gets formatted with ``type(self)`` and the property name.
#    1179 """
#    1180 ret = []
# -> 1181 with cbook._setattr_cm(self, eventson=False):
#    1182     for k, v in props.items():
#    1183         # Allow attributes we want to be able to update through
#    1184         # art.update, art.set, setp.
#    1185         if k == "axes":
#
# File c:\Users\zama\anaconda3\envs\test_github_bug_data_collector\Lib\contextlib.py:132, in _GeneratorContextManager.__enter__(self)
#     125 class _GeneratorContextManager(
#     126     _GeneratorContextManagerBase,
#     127     AbstractContextManager,
#     128     ContextDecorator,
#     129 ):
#     130     """Helper for @contextmanager decorator."""
# --> 132     def __enter__(self):
#     133         # do not keep args and kwds alive unnecessarily
#     134         # they are only needed for recreation, which is not possible anymore
#     135         del self.args, self.kwds, self.func
#     136         try:
#
# KeyboardInterrupt:
